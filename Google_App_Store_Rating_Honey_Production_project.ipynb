# %% [markdown]
# # EDA & Data Preprocessing on Google App Store Rating Dataset.

# %% [markdown]
# # PART-I

# %% [markdown]
# # 1. Import required libraries and read the dataset

# %%
#Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')


df=pd.read_csv('Apps_data.csv')
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# # 2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.shape
# Out:
# (10841, 13)

# %% [markdown]
# # 3. Check summary statistics of the dataset. List out the columns that need to be worked upon for model building.

# %%
#Summary statistics of the dataset.
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.describe(include='object')
# Out:
#            App Category Reviews                Size    Installs   Type  Price  \
# count    10841    10841   10841               10841       10841  10840  10841
# unique    9660       34    6002                 462          22      3     93
# top     ROBLOX   FAMILY       0  Varies with device  1,000,000+   Free      0
# freq         9     1972     596                1695        1579  10039  10040
#
#        Content Rating Genres    Last Updated         Current Ver Android Ver
# count           10840  10841           10841               10833       10838
# unique              6    120            1378                2832          33
# top          Everyone  Tools  August 3, 2018  Varies with device  4.1 and up
# freq             8714    842             326                1459        2451

# %% [markdown]
# <font size=4><b>Columns that need to be worked upon for model building.</b></font>
#
# * Category
# * Type
# * Rating
# * Content_Rating
# * Price
# * Install
# * Size

# %% [markdown]
# # 4. Check if there are any duplicate records in the dataset? if any drop them.

# %%
#Checking for duplicates
df.duplicated().sum()
# Out:
# 483

# %%
#Dropping the duplicates
df=df.drop_duplicates()
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# # 5. Check the unique categories of the column 'Category', Is there any invalid category? If yes, drop them.

# %%
#checking invalid category and dropping them
df=df[df['Category']!='1.9']
df['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %% [markdown]
# # 6. Check if there are missing values present in the column Rating, If any? drop them and and create a new column as 'Rating_category' by converting ratings to high and low categories(>3.5 is high rest low)

# %%
#Sum of null values
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1465
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       0
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          2
# dtype: int64

# %%
#Dropping null values
df=df.dropna()
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#Again checking null values whether it gets dropped or not
df.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
#Checking the count of the values in 'Rating' column
df['Rating'].value_counts()
# Out:
# 4.4    1031
# 4.3    1016
# 4.5     976
# 4.2     887
# 4.6     768
# 4.1     656
# 4.0     538
# 4.7     484
# 3.9     372
# 3.8     293
# 5.0     271
# 3.7     231
# 4.8     228
# 3.6     169
# 3.5     157
# 3.4     127
# 3.3     101
# 4.9      87
# 3.0      82
# 3.1      69
# 3.2      63
# 2.9      45
# 2.8      40
# 2.6      24
# 2.7      23
# 2.5      20
# 2.3      20
# 2.4      19
# 1.0      16
# 2.2      14
# 1.9      12
# 2.0      12
# 1.7       8
# 1.8       8
# 2.1       8
# 1.6       4
# 1.4       3
# 1.5       3
# 1.2       1
# Name: Rating, dtype: int64

# %%
#Creating a new column named as 'Rating_category'
df['Rating_category']=df['Rating'].apply(lambda x: 'high' if x>3.5 else 'low')
df['Rating_category']
# Out:
# 0        high
# 1        high
# 2        high
# 3        high
# 4        high
#          ...
# 10834    high
# 10836    high
# 10837    high
# 10839    high
# 10840    high
# Name: Rating_category, Length: 8886, dtype: object

# %%
#Checking the count of the values in 'Rating_category' column
df['Rating_category'].value_counts()
# Out:
# high    8007
# low      879
# Name: Rating_category, dtype: int64

# %% [markdown]
# # 7. Check the distribution of the newly created column 'Rating_category' and comment on the distribution.

# %%
#To check the distribution we can plot the distribution plot
sns.displot(df['Rating_category'])
plt.show()

# %% [markdown]
# <font size=5><b>Inference</b></font>
#
# From the plot it is inferred that high value has more counts than low value

# %% [markdown]
# # 8. Convert the column "Reviews'' to numeric data type and check the presence of outliers in the column and handle the outliers using a transformation approach.(Hint: Use log transformation)

# %%
#Converting the datatype
df['Reviews']=df['Reviews'].str.replace('M','*1000000').apply(eval)
df['Reviews']
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10834         7
# 10836        38
# 10837         4
# 10839       114
# 10840    398307
# Name: Reviews, Length: 8886, dtype: int64

# %%
#Checking the outliers
sns.boxplot(df['Reviews'])
plt.show()

# %%
#Removing the outliers
df['Reviews']=np.log(df['Reviews'])
df['Reviews']
plt.boxplot(df['Reviews'])
plt.show()

# %%
plt.boxplot([df['Reviews']])
plt.show()

# %% [markdown]
# # 9. The column 'Size' contains alphanumeric values, treat the non numeric data and convert the column into suitable data type. (hint: Replace M with 1 million and K with 1 thousand, and drop the entries where size='Varies with device')

# %%
#Removing 'Varies with device' in Size column and replacing M with 1000000 and k with 1000 and + with ''
df=df[df['Size']!='Varies with device']
df['Size']=df['Size'].str.replace('M','*1000000').str.replace('k','*1000').str.replace('+','').apply(eval)
df['Size']
# Out:
# 0        19000000.0
# 1        14000000.0
# 2         8700000.0
# 3        25000000.0
# 4         2800000.0
#             ...
# 10833      619000.0
# 10834     2600000.0
# 10836    53000000.0
# 10837     3600000.0
# 10840    19000000.0
# Name: Size, Length: 7418, dtype: float64

# %% [markdown]
# # 10. Check the column 'Installs', treat the unwanted characters and convert the column into a suitable data type.

# %%
#Replacing unwanted characters in the column 'Installs' and changing the datatype
df['Installs']=df['Installs'].str.replace(',','').str.replace('+','').astype(int)
df['Installs']
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10833        1000
# 10834         500
# 10836        5000
# 10837         100
# 10840    10000000
# Name: Installs, Length: 7418, dtype: int32

# %% [markdown]
# # 11. Check the column 'Price' , remove the unwanted characters and convert the column into a suitable data type.

# %%
#Removing the unwanted characters and converting the datatype
df['Price']=df['Price'].str.replace('$','').astype(float)
df['Price'].unique()
# Out:
# array([  0.  ,   4.99,   6.99,   7.99,   3.99,   5.99,   2.99,   1.99,
#          9.99,   0.99,   9.  ,   5.49,  10.  ,  24.99,  11.99,  79.99,
#         16.99,  14.99,  29.99,  12.99,   3.49,  10.99,   7.49,   1.5 ,
#         19.99,  15.99,  33.99,  39.99,   2.49,   4.49,   1.7 ,   1.49,
#          3.88, 399.99,  17.99, 400.  ,   3.02,   1.76,   4.84,   4.77,
#          1.61,   1.59,   6.49,   1.29, 299.99, 379.99,  37.99,  18.99,
#        389.99,   8.49,   1.75,  14.  ,   2.  ,   3.08,   2.59,  19.4 ,
#         15.46,   8.99,   3.04,  13.99,   4.29,   3.28,   4.6 ,   1.  ,
#          2.9 ,   1.97,   2.56,   1.2 ])

# %% [markdown]
# # 12. Drop the columns which you think redundant for the analysis.(suggestion: drop column 'rating', since we created a new feature from it (i.e. rating_category) and the columns 'App', 'Rating' ,'Genres','Last Updated', 'Current Ver','Android Ver' columns since which are redundant for our analysis)

# %%
# Drop the columns which considered as redundant for the analysis
df=df.drop(['App','Rating' ,'Genres','Last Updated','Current Ver','Android Ver'],axis=1)
df
# Out:
#                   Category    Reviews        Size  Installs  Type  Price  \
# 0           ART_AND_DESIGN   5.068904  19000000.0     10000  Free    0.0
# 1           ART_AND_DESIGN   6.874198  14000000.0    500000  Free    0.0
# 2           ART_AND_DESIGN  11.379508   8700000.0   5000000  Free    0.0
# 3           ART_AND_DESIGN  12.281384  25000000.0  50000000  Free    0.0
# 4           ART_AND_DESIGN   6.874198   2800000.0    100000  Free    0.0
# ...                    ...        ...         ...       ...   ...    ...
# 10833  BOOKS_AND_REFERENCE   3.784190    619000.0      1000  Free    0.0
# 10834               FAMILY   1.945910   2600000.0       500  Free    0.0
# 10836               FAMILY   3.637586  53000000.0      5000  Free    0.0
# 10837               FAMILY   1.386294   3600000.0       100  Free    0.0
# 10840            LIFESTYLE  12.894978  19000000.0  10000000  Free    0.0
#
#       Content Rating Rating_category
# 0           Everyone            high
# ...

# %% [markdown]
# # 13. Encode the categorical columns.

# %%
#Encoding columns using labelEncoder
le=LabelEncoder()
df['Rating_category']=le.fit_transform(df['Rating_category'])
df=pd.get_dummies(df,drop_first=True)
df
# Out:
#          Reviews        Size  Installs  Price  Rating_category  \
# 0       5.068904  19000000.0     10000    0.0                0
# 1       6.874198  14000000.0    500000    0.0                0
# 2      11.379508   8700000.0   5000000    0.0                0
# 3      12.281384  25000000.0  50000000    0.0                0
# 4       6.874198   2800000.0    100000    0.0                0
# ...          ...         ...       ...    ...              ...
# 10833   3.784190    619000.0      1000    0.0                0
# 10834   1.945910   2600000.0       500    0.0                0
# 10836   3.637586  53000000.0      5000    0.0                0
# 10837   1.386294   3600000.0       100    0.0                0
# 10840  12.894978  19000000.0  10000000    0.0                0
#
#        Category_AUTO_AND_VEHICLES  Category_BEAUTY  \
# 0                               0                0
# 1                               0                0
# 2                               0                0
# ...

# %% [markdown]
# # 14. Segregate the target and independent features (Hint: Use Rating_category as the target)

# %%
#Segregating the target and independent features
x=df.drop(['Rating_category'],axis=1)
y=df[['Rating_category']]

# %% [markdown]
# # 15. Split the dataset into train and test.

# %%
#Splitting
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=33)

# %% [markdown]
# # 16. Standardize the data, so that the values are within a particular range.

# %%
#MinMaxScaler
ss=MinMaxScaler()
x_train.iloc[:,:3]=ss.fit_transform(x_train.iloc[:,:3])
x_train
# Out:
#         Reviews      Size  Installs  Price  Category_AUTO_AND_VEHICLES  \
# 4203   0.472235  0.129878  0.000010  17.99                           0
# 1832   0.561844  0.349909  0.000100   1.99                           0
# 1166   0.389964  0.139880  0.000010   0.00                           0
# 10614  0.245036  0.080871  0.000005   0.00                           0
# 3373   0.715440  0.139880  0.010000   0.00                           0
# ...         ...       ...       ...    ...                         ...
# 4305   0.440561  0.619947  0.000100   0.00                           0
# 953    0.645974  0.319905  0.010000   0.00                           0
# 8659   0.644962  0.129878  0.001000   0.00                           0
# 3955   0.222024  0.073870  0.000010   0.00                           0
# 10476  0.358321  0.075871  0.000050   0.00                           0
#
#        Category_BEAUTY  Category_BOOKS_AND_REFERENCE  Category_BUSINESS  \
# ...

# %% [markdown]
# # Data Visualization on Honey Production dataset using seaborn and matplotlib libraries.

# %% [markdown]
# # PART-II

# %% [markdown]
# # 1. Import required libraries and read the dataset.

# %%
#Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')

dh=pd.read_csv('honeyproduction.csv')
dh
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %% [markdown]
# # 2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
#Info of the data
dh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.2+ KB

# %%
#shape of the data
df.shape
# Out:
# (7418, 43)

# %%
#checking summary stats of numerical column
dh.describe()
# Out:
#               numcol  yieldpercol     totalprod        stocks  priceperlb  \
# count     626.000000   626.000000  6.260000e+02  6.260000e+02  626.000000
# mean    60284.345048    62.009585  4.169086e+06  1.318859e+06    1.409569
# std     91077.087231    19.458754  6.883847e+06  2.272964e+06    0.638599
# min      2000.000000    19.000000  8.400000e+04  8.000000e+03    0.490000
# 25%      9000.000000    48.000000  4.750000e+05  1.430000e+05    0.932500
# 50%     26000.000000    60.000000  1.533000e+06  4.395000e+05    1.360000
# 75%     63750.000000    74.000000  4.175250e+06  1.489500e+06    1.680000
# max    510000.000000   136.000000  4.641000e+07  1.380000e+07    4.150000
#
#           prodvalue         year
# count  6.260000e+02   626.000000
# mean   4.715741e+06  2004.864217
# std    7.976110e+06     4.317306
# min    1.620000e+05  1998.000000
# 25%    7.592500e+05  2001.000000
# 50%    1.841500e+06  2005.000000
# 75%    4.703250e+06  2009.000000
# ...

# %%
#checking summary stats of categorical column
dh.describe(include='object')
# Out:
#        state
# count    626
# unique    44
# top       AL
# freq      15

# %% [markdown]
# # 3. Display the percentage distribution of the data in each year using the pie chart.

# %%
plt.figure(figsize=(10,15))
dh['year'].value_counts().plot(kind='pie',autopct='%0.3f%%')
plt.title('Distribution of the data in a year')
plt.show()

# %% [markdown]
# # 4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
sns.displot(dh['priceperlb'])
plt.title('Distribution of price per lb')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <font size=5><b>Inference</b></font>
#
# From the graph it is inferred that priceperlb has positive skewness

# %% [markdown]
# # 5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and write your findings.

# %%
sns.scatterplot(x=dh['numcol'],y=dh['prodvalue'])
plt.title('relationship between numcol and prodvalue')
plt.show()

# %% [markdown]
# <font size=5><b>Inference</b></font>
#
# From the graph it is inferred that prodvalue increases when numcol value increases.

# %% [markdown]
# # 6. Plot and understand the relationship between categorical variable 'year' and a numerical variable 'prodvalue' through boxplot, and write your findings.

# %%
plt.figure(figsize=(10,10))
sns.boxplot(x=dh['year'],y=dh['prodvalue'])
plt.title('relationship between year and prodvalue')
plt.show()

# %% [markdown]
# <font size=5><b>Inference</b></font>
#
# From the graph,
# * It is inferred that there is only a slight change in median of prodvalue over the years
# * In the year 2010, prodvalue has maximum number of outliers

# %% [markdown]
# # 7. Visualize and understand the relationship between the multiple pairs of variables throughout different years using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year')

# %%
sns.pairplot(dh[['numcol','yieldpercol','totalprod','prodvalue','year']],hue='year')
plt.show()

# %%
sns.pairplot(dh,vars=['numcol','yieldpercol','totalprod','prodvalue'],hue='year')
plt.show()

# %% [markdown]
# <font size=5><b>Inference</b></font>
#
# From the graph it is inferred that the diagonal values are univariate histogram for each attribute

# %% [markdown]
# # 8. Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'stocks', 'price per lb', 'prodvalue')

# %%
sns.heatmap(dh[['numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb', 'prodvalue']].corr(),annot=True)
plt.show()

# %% [markdown]
# <font size=5><b>Inference</b></font>
#
# * From the graph it is inferred that the columns totalprod and numcol has highest(positive) correlation values
# * From the graph it is inferred that the columns priceperlab and yieldpercol has lowest(negative) correlation values
